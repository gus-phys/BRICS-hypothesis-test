# %% [markdown]
# # Trabalho em grupo - Ana Luisa, Ananda e Luis
#
# ## - HIPOTESE: Como a economia afeta o setor publico e privado de maneiras diferentes
#
# ## - Dataset: [BRICS - World Bank Indicator](https://www.kaggle.com/arslanali4343/real-estate-dataset)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Importando os datasets e abrindo para ver o conteúdo:

# %%
df_economy = pd.read_csv('data/BRICS Development Indicators/Economy_Data.csv', sep= ';')
df_private_sector = pd.read_csv('data/BRICS Development Indicators/PrivateSector_Data.csv', sep=';')
df_public_sector = pd.read_csv('data/BRICS Development Indicators/PublicSector_Indicators.csv', sep=';')

# %% [markdown]
# ---

# %% [markdown]
# ## 2) Criando DataFrames

# %% [markdown]
# Criação de um 'dataframe' onde cada valor de 'SeriesName' se torne uma coluna.
# Vamos tomar a média por ano para cada 'feature'.

# %% [markdown]
# ### a) Economia

# %%
df_economy['Year'] = df_economy['Year'].astype('int64')

# %%
def SeriesName_DF(dataframe):
    df_mult = dataframe[["SeriesName", "Year", "Value"]].groupby(["Year", "SeriesName"]).mean()
    SeriesName_list = df_mult.index.get_level_values(1).unique().to_list()
    
    df_seriesname = pd.DataFrame()
    sn_column_list = []
    
    for seriesname in SeriesName_list:
        sn_column = df_mult[df_mult.index.get_level_values(1)==seriesname].droplevel(1).rename(columns={"Value" : seriesname})
        sn_column_list.append(sn_column)
    df_seriesname = pd.concat(sn_column_list, axis=1)
    
    targets = dataframe[["SeriesName", "Year", "Value"]].groupby(["Year"]).mean()
    
    return pd.concat([df_seriesname, targets], axis=1)

# %%
df_economy_SN = SeriesName_DF(df_economy)
df_economy_SN.head()
# Out:
#       Adjusted net national income (annual % growth)  \
# Year
# 1970                                             NaN
# 1971                                        6.471394
# 1972                                        6.011575
# 1973                                       10.101633
# 1974                                        2.146270
#
#       Adjusted net national income (constant 2010 US$)  \
# Year
# 1970                                      2.917154e+11
# 1971                                      2.413961e+11
# 1972                                      2.616514e+11
# 1973                                      2.888742e+11
# 1974                                      2.974932e+11
#
#       Adjusted net national income (current US$)  \
# Year
# 1970                                6.029434e+10
# 1971                                5.380672e+10
# 1972                                6.012322e+10
# 1973                                7.523094e+10
# 1974                                8.604191e+10
#
#       Adjusted net national income per capita (annual % growth)  \
# Year
# 1970                                                NaN
# 1971                                           3.983653
# 1972                                           3.431272
# 1973                                           7.421891
# 1974                                          -0.324611
#
#       Adjusted net national income per capita (constant 2010 US$)  \
# Year
# 1970                                        2232.655378
# 1971                                        2972.407176
# 1972                                        3137.592240
# 1973                                        3448.301025
# 1974                                        3532.170799
#
#       Adjusted net national income per capita (current US$)  \
# Year
# 1970                                         202.095920
# 1971                                         356.494462
# 1972                                         381.391654
# 1973                                         498.975816
# 1974                                         606.901334
#
#       Adjusted net savings, excluding particulate emission damage (% of GNI)  \
# Year
# 1970                                                NaN
# 1971                                          15.470408
# 1972                                          16.193499
# 1973                                          21.277543
# 1974                                          22.685263
#
#       Adjusted net savings, excluding particulate emission damage (current US$)  \
# Year
# 1970                                                NaN
# 1971                                       3.044258e+09
# 1972                                       3.344763e+09
# 1973                                       6.036556e+09
# 1974                                       8.066478e+09
#
#       Adjusted net savings, including particulate emission damage (% of GNI)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Adjusted net savings, including particulate emission damage (current US$)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       ...  Total reserves in months of imports  \
# Year  ...
# 1970  ...                             2.358050
# 1971  ...                             1.551095
# 1972  ...                             3.764724
# 1973  ...                             3.962601
# 1974  ...                             3.864540
#
#       Total reserves minus gold (current US$)  Trade (% of GDP)  \
# Year
# 1970                             7.501700e+08         18.231993
# 1971                             9.681897e+08         18.442241
# 1972                             1.885998e+09         19.099327
# 1973                             2.552525e+09         20.357388
# 1974                             2.206845e+09         24.488069
#
#       Trade in services (% of GDP)  \
# Year
# 1970                      7.631499
# 1971                      8.119831
# 1972                      7.718721
# 1973                      7.397890
# 1974                      7.469152
#
#       Transport services (% of service exports, BoP)  \
# Year
# 1970                                       20.000000
# 1971                                       20.673610
# 1972                                       22.397982
# 1973                                       24.484802
# 1974                                       24.594337
#
#       Transport services (% of service imports, BoP)  \
# Year
# 1970                                       44.349315
# 1971                                       44.103132
# 1972                                       38.798445
# 1973                                       41.193563
# 1974                                       47.875564
#
#       Travel services (% of service exports, BoP)  \
# Year
# 1970                                    56.428571
# 1971                                    59.044769
# 1972                                    56.474733
# 1973                                    57.884607
# 1974                                    59.201869
#
#       Travel services (% of service imports, BoP)  \
# Year
# 1970                                    23.287671
# 1971                                    23.600494
# 1972                                    26.340076
# 1973                                    24.295091
# 1974                                    25.252027
#
#       Use of IMF credit (DOD, current US$)         Value
# Year
# 1970                          0.000000e+00  1.753322e+11
# 1971                          0.000000e+00  1.781317e+11
# 1972                          0.000000e+00  1.793717e+11
# 1973                          2.493227e+07  1.901448e+11
# 1974                          2.028382e+08  1.938223e+11
#
# [5 rows x 348 columns]

# %% [markdown]
# ### b) Setor privado

# %%
df_private_sector['Year'] = df_private_sector['Year'].astype('int64')

# %%
df_private_SN = SeriesName_DF(df_private_sector)
df_private_SN.head()
# Out:
#       Agricultural raw materials exports (% of merchandise exports)  \
# Year
# 1970                                           8.725796
# 1971                                           7.953770
# 1972                                           7.574604
# 1973                                           6.800030
# 1974                                           6.642671
#
#       Agricultural raw materials imports (% of merchandise imports)  \
# Year
# 1970                                           5.529160
# 1971                                           5.401722
# 1972                                           5.318545
# 1973                                           3.482063
# 1974                                           2.772902
#
#       Average number of visits or required meetings with tax officials (for affected firms)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Average time to clear exports through customs (days)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Binding coverage, all products (%)  \
# Year
# 1970                                 NaN
# 1971                                 NaN
# 1972                                 NaN
# 1973                                 NaN
# 1974                                 NaN
#
#       Binding coverage, manufactured products (%)  \
# Year
# 1970                                          NaN
# 1971                                          NaN
# 1972                                          NaN
# 1973                                          NaN
# 1974                                          NaN
#
#       Binding coverage, primary products (%)  \
# Year
# 1970                                     NaN
# 1971                                     NaN
# 1972                                     NaN
# 1973                                     NaN
# 1974                                     NaN
#
#       Bound rate, simple mean, all products (%)  \
# Year
# 1970                                        NaN
# 1971                                        NaN
# 1972                                        NaN
# 1973                                        NaN
# 1974                                        NaN
#
#       Bound rate, simple mean, manufactured products (%)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Bound rate, simple mean, primary products (%)  ...  \
# Year                                                 ...
# 1970                                            NaN  ...
# 1971                                            NaN  ...
# 1972                                            NaN  ...
# 1973                                            NaN  ...
# 1974                                            NaN  ...
#
#       Time to obtain an electrical connection (days)  \
# Year
# 1970                                             NaN
# 1971                                             NaN
# 1972                                             NaN
# 1973                                             NaN
# 1974                                             NaN
#
#       Time to prepare and pay taxes (hours)  \
# Year
# 1970                                    NaN
# 1971                                    NaN
# 1972                                    NaN
# 1973                                    NaN
# 1974                                    NaN
#
#       Time to resolve insolvency (years)  \
# Year
# 1970                                 NaN
# 1971                                 NaN
# 1972                                 NaN
# 1973                                 NaN
# 1974                                 NaN
#
#       Total tax and contribution rate (% of profit)  \
# Year
# 1970                                            NaN
# 1971                                            NaN
# 1972                                            NaN
# 1973                                            NaN
# 1974                                            NaN
#
#       Transport services (% of commercial service exports)  \
# Year
# 1970                                          20.487805
# 1971                                          21.007996
# 1972                                          22.635121
# 1973                                          24.701632
# 1974                                          24.769729
#
#       Transport services (% of commercial service imports)  \
# Year
# 1970                                          45.279720
# 1971                                          44.965126
# 1972                                          39.710759
# 1973                                          42.182462
# 1974                                          48.590172
#
#       Travel services (% of commercial service exports)  \
# Year
# 1970                                          57.804878
# 1971                                          59.999790
# 1972                                          57.072661
# 1973                                          58.397215
# 1974                                          59.624060
#
#       Travel services (% of commercial service imports)  \
# Year
# 1970                                          23.776224
# 1971                                          24.061765
# 1972                                          26.959441
# 1973                                          24.878323
# 1974                                          25.628948
#
#       Value lost due to electrical outages (% of sales for affected firms)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#              Value
# Year
# 1970  3.456341e+08
# 1971  3.851163e+08
# 1972  4.602504e+08
# 1973  6.650080e+08
# 1974  9.227325e+08
#
# [5 rows x 171 columns]

# %% [markdown]
# ### C) Setor público

# %%
df_public_sector['Year'] = df_public_sector['Year'].astype('int64')

# %%
df_public_SN = SeriesName_DF(df_public_sector)
df_public_SN.head()
# Out:
#       Adequacy of social insurance programs (% of total welfare of beneficiary households)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Adequacy of social protection and labor programs (% of total welfare of beneficiary households)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Adequacy of unemployment benefits and ALMP (% of total welfare of beneficiary households)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Air transport, freight (million ton-km)  \
# Year
# 1970                               105.733336
# 1971                               117.500000
# 1972                               153.733337
# 1973                               201.966670
# 1974                               181.150002
#
#       Air transport, passengers carried  \
# Year
# 1970                       2.510133e+06
# 1971                       2.708167e+06
# 1972                       3.275100e+06
# 1973                       3.849267e+06
# 1974                       3.341600e+06
#
#       Air transport, registered carrier departures worldwide  \
# Year
# 1970                                       91666.666667
# 1971                                       86666.666667
# 1972                                      100300.000000
# 1973                                      105100.000000
# 1974                                       87675.000000
#
#       Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Annualized average growth rate in per capita real survey mean consumption or income, total population (%)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Armed forces personnel (% of total labor force)  ...  \
# Year                                                   ...
# 1970                                              NaN  ...
# 1971                                              NaN  ...
# 1972                                              NaN  ...
# 1973                                              NaN  ...
# 1974                                              NaN  ...
#
#       Unemployment, youth male (% of male labor force ages 15-24) (national estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Unemployment, youth total (% of total labor force ages 15-24) (national estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Vulnerable employment, male (% of male employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Vulnerable employment, total (% of total employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Wage and salaried workers, female (% of female employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Wage and salaried workers, male (% of male employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#       Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# Year
# 1970                                                NaN
# 1971                                                NaN
# 1972                                                NaN
# 1973                                                NaN
# 1974                                                NaN
#
#              Value
# Year
# 1970  3.144226e+08
# 1971  6.331153e+08
# 1972  5.603605e+08
# 1973  6.083082e+08
# 1974  4.148702e+09
#
# [5 rows x 328 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 3) Seleção de Características

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### a) Economia

# %% [markdown]
# #### Eliminando todos os NaN

# %%
df_economy_SN.isna().sum().sort_values(ascending=False)
# Out:
# Net ODA provided, total (constant 2015 US$)                    50
# Data from database: World Development Indicators               50
# Net official flows from UN agencies, UNECE (current US$)       50
# Net official flows from UN agencies, UNEP (current US$)        50
# Net official flows from UN agencies, UNPBF (current US$)       50
#                                                                ..
# Gross fixed capital formation, private sector (current LCU)     0
# Gross fixed capital formation, private sector (% of GDP)        0
# Gross fixed capital formation (current US$)                     0
# Gross fixed capital formation (current LCU)                     0
# Value                                                           0
# Length: 348, dtype: int64

# %%
df_economy_SN.dropna(axis=1, inplace=True)

# %% [markdown]
# #### Seleção das características mais úteis

# %% [markdown]
# Aplicaremos o método apresentado no do Amr, *Hands-On Machine Learning with scikit-learn and Scientific Python Toolkits*.

# %%
df_train, df_test = train_test_split(df_economy_SN, test_size=0.3)

# %%
X_train = df_train.drop('Value', axis=1)
X_test = df_train.drop('Value', axis=1)

# %%
y_train = df_train['Value']
y_train = df_train['Value']

# %% [markdown]
# #### VarianceThreshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
vt = VarianceThreshold(threshold=0)

# %%
vt.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
X_train = X_train.iloc[:, vt.get_support()]
X_test = X_test.iloc[:, vt.get_support()]

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'Variance': vt.variances_
    }
).sort_values('Variance', ascending=True)
# Out:
#                                                Feature      Variance
# 170          Personal remittances, received (% of GDP)  7.997631e-02
# 176  Public and publicly guaranteed debt service (%...  2.181122e-01
# 46   Foreign direct investment, net outflows (% of ...  3.100156e-01
# 44   Foreign direct investment, net inflows (% of GDP)  9.014815e-01
# 193                      Total debt service (% of GNI)  9.527019e-01
# ..                                                 ...           ...
# 49                                  GDP (constant LCU)  6.042579e+13
# 107  Gross value added at basic prices (GVA) (curre...  6.870604e+13
# 98            Gross national expenditure (current LCU)  7.767490e+13
# 60                                   GNI (current LCU)  7.833538e+13
# 50                                   GDP (current LCU)  7.940060e+13
#
# [204 rows x 2 columns]

# %% [markdown]
# #### Filtros

# %% [markdown]
# Aplicaremos os métodos **ANOVA (F-values)** e **mutual information**

# %%
from sklearn.feature_selection import f_regression

# %%
f, p = f_regression(X_train, y_train)

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
mi = mutual_info_regression(X_train, y_train)

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'F': f,
        'MI': mi,
        'Variance': vt.variances_
    }
).sort_values('F', ascending=False).style.bar(subset=['F', 'MI', 'Variance'], color='grey')
# Out:
# <style type="text/css">
# #T_25366_row0_col1, #T_25366_row11_col2, #T_25366_row29_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 100.0%, transparent 100.0%);
# }
# #T_25366_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 93.7%, transparent 93.7%);
# }
# #T_25366_row0_col3, #T_25366_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 4.1%, transparent 4.1%);
# }
# #T_25366_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 82.3%, transparent 82.3%);
# }
# #T_25366_row1_col2, #T_25366_row24_col2, #T_25366_row35_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 86.5%, transparent 86.5%);
# }
# #T_25366_row1_col3, #T_25366_row2_col3, #T_25366_row145_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.6%, transparent 1.6%);
# }
# #T_25366_row2_col1, #T_25366_row52_col2, #T_25366_row129_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 81.9%, transparent 81.9%);
# }
# #T_25366_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 93.3%, transparent 93.3%);
# }
# #T_25366_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 72.0%, transparent 72.0%);
# }
# #T_25366_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 88.4%, transparent 88.4%);
# }
# #T_25366_row3_col3, #T_25366_row42_col3, #T_25366_row45_col3, #T_25366_row86_col3, #T_25366_row110_col1, #T_25366_row111_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.9%, transparent 1.9%);
# }
# #T_25366_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 63.3%, transparent 63.3%);
# }
# #T_25366_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 89.3%, transparent 89.3%);
# }
# #T_25366_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 59.0%, transparent 59.0%);
# }
# #T_25366_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 99.7%, transparent 99.7%);
# }
# #T_25366_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 30.9%, transparent 30.9%);
# }
# #T_25366_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 55.5%, transparent 55.5%);
# }
# #T_25366_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 97.6%, transparent 97.6%);
# }
# #T_25366_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 17.1%, transparent 17.1%);
# }
# #T_25366_row7_col1, #T_25366_row128_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 52.4%, transparent 52.4%);
# }
# #T_25366_row7_col2, #T_25366_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 95.9%, transparent 95.9%);
# }
# #T_25366_row7_col3, #T_25366_row8_col3, #T_25366_row47_col3, #T_25366_row51_col3, #T_25366_row57_col3, #T_25366_row68_col3, #T_25366_row75_col3, #T_25366_row84_col3, #T_25366_row90_col3, #T_25366_row92_col3, #T_25366_row93_col3, #T_25366_row94_col3, #T_25366_row97_col3, #T_25366_row101_col3, #T_25366_row106_col3, #T_25366_row107_col3, #T_25366_row108_col3, #T_25366_row109_col3, #T_25366_row111_col3, #T_25366_row112_col3, #T_25366_row114_col3, #T_25366_row115_col3, #T_25366_row116_col3, #T_25366_row120_col3, #T_25366_row123_col3, #T_25366_row125_col3, #T_25366_row126_col3, #T_25366_row127_col3, #T_25366_row128_col3, #T_25366_row130_col3, #T_25366_row131_col3, #T_25366_row133_col3, #T_25366_row134_col3, #T_25366_row135_col3, #T_25366_row136_col3, #T_25366_row137_col3, #T_25366_row138_col3, #T_25366_row139_col3, #T_25366_row140_col3, #T_25366_row141_col3, #T_25366_row142_col3, #T_25366_row143_col3, #T_25366_row144_col3, #T_25366_row146_col3, #T_25366_row148_col3, #T_25366_row149_col3, #T_25366_row150_col3, #T_25366_row151_col3, #T_25366_row152_col3, #T_25366_row153_col3, #T_25366_row154_col3, #T_25366_row156_col3, #T_25366_row157_col3, #T_25366_row159_col3, #T_25366_row160_col3, #T_25366_row161_col3, #T_25366_row162_col3, #T_25366_row163_col3, #T_25366_row164_col3, #T_25366_row165_col3, #T_25366_row166_col3, #T_25366_row167_col3, #T_25366_row169_col3, #T_25366_row170_col3, #T_25366_row171_col3, #T_25366_row172_col3, #T_25366_row173_col3, #T_25366_row174_col3, #T_25366_row175_col1, #T_25366_row175_col3, #T_25366_row176_col1, #T_25366_row176_col3, #T_25366_row177_col1, #T_25366_row177_col3, #T_25366_row178_col1, #T_25366_row178_col3, #T_25366_row179_col1, #T_25366_row179_col3, #T_25366_row180_col1, #T_25366_row180_col3, #T_25366_row181_col1, #T_25366_row182_col1, #T_25366_row182_col3, #T_25366_row183_col1, #T_25366_row183_col3, #T_25366_row184_col1, #T_25366_row184_col3, #T_25366_row185_col1, #T_25366_row185_col3, #T_25366_row186_col1, #T_25366_row186_col3, #T_25366_row187_col1, #T_25366_row187_col3, #T_25366_row188_col1, #T_25366_row188_col3, #T_25366_row189_col1, #T_25366_row189_col3, #T_25366_row190_col1, #T_25366_row190_col3, #T_25366_row191_col1, #T_25366_row191_col3, #T_25366_row192_col1, #T_25366_row192_col3, #T_25366_row193_col1, #T_25366_row193_col3, #T_25366_row194_col1, #T_25366_row195_col1, #T_25366_row195_col3, #T_25366_row196_col1, #T_25366_row196_col3, #T_25366_row197_col1, #T_25366_row197_col3, #T_25366_row198_col1, #T_25366_row198_col3, #T_25366_row199_col1, #T_25366_row199_col3, #T_25366_row200_col1, #T_25366_row200_col3, #T_25366_row201_col1, #T_25366_row201_col3, #T_25366_row202_col1, #T_25366_row202_col3, #T_25366_row203_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.0%, transparent 0.0%);
# }
# #T_25366_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 51.9%, transparent 51.9%);
# }
# #T_25366_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 51.3%, transparent 51.3%);
# }
# #T_25366_row9_col2, #T_25366_row49_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 85.5%, transparent 85.5%);
# }
# #T_25366_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 2.5%, transparent 2.5%);
# }
# #T_25366_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 50.9%, transparent 50.9%);
# }
# #T_25366_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 87.8%, transparent 87.8%);
# }
# #T_25366_row10_col3, #T_25366_row97_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 4.2%, transparent 4.2%);
# }
# #T_25366_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 50.4%, transparent 50.4%);
# }
# #T_25366_row11_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 33.5%, transparent 33.5%);
# }
# #T_25366_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 47.0%, transparent 47.0%);
# }
# #T_25366_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 99.1%, transparent 99.1%);
# }
# #T_25366_row12_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 31.5%, transparent 31.5%);
# }
# #T_25366_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 44.7%, transparent 44.7%);
# }
# #T_25366_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 93.1%, transparent 93.1%);
# }
# #T_25366_row13_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 33.7%, transparent 33.7%);
# }
# #T_25366_row14_col1, #T_25366_row139_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 43.6%, transparent 43.6%);
# }
# #T_25366_row14_col2, #T_25366_row31_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 93.8%, transparent 93.8%);
# }
# #T_25366_row14_col3, #T_25366_row54_col3, #T_25366_row76_col1, #T_25366_row77_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 9.9%

# %% [markdown]
# ### b) Setor privado

# %% [markdown]
# Eliminando todos os NaN

# %%
df_private_SN.isna().sum().sort_values(ascending=False)
# Out:
# Data from database: World Development Indicators                       50
# Last Updated: 10/15/2020                                               50
# Investment in ICT with private participation (current US$)             49
# Ease of doing business index (1=most business-friendly regulations)    49
# Firms that spend on R&D (% of firms)                                   47
#                                                                        ..
# Merchandise exports (current US$)                                       0
# Agricultural raw materials imports (% of merchandise imports)           0
# Merchandise imports (current US$)                                       0
# Merchandise trade (% of GDP)                                            0
# Value                                                                   0
# Length: 171, dtype: int64

# %%
df_private_SN.dropna(axis=1, inplace=True)

# %% [markdown]
# #### Seleção das características mais úteis

# %%
df_train, df_test = train_test_split(df_private_SN, test_size=0.3)

# %%
X_train = df_train.drop('Value', axis=1)
X_test = df_train.drop('Value', axis=1)

# %%
y_train = df_train['Value']
y_train = df_train['Value']

# %% [markdown]
# #### VarianceThreshold

# %%
vt = VarianceThreshold(threshold=0)

# %%
vt.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
X_train = X_train.iloc[:, vt.get_support()]
X_test = X_test.iloc[:, vt.get_support()]

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'Variance': vt.variances_
    }
).sort_values('Variance', ascending=True)
# Out:
#                                               Feature      Variance
# 18  Ores and metals imports (% of merchandise impo...  1.093622e+00
# 1   Agricultural raw materials imports (% of merch...  1.498981e+00
# 0   Agricultural raw materials exports (% of merch...  3.238865e+00
# 10  Insurance and financial services (% of commerc...  4.386225e+00
# 11  Insurance and financial services (% of commerc...  4.976007e+00
# 17  Ores and metals exports (% of merchandise expo...  5.128521e+00
# 7             Food imports (% of merchandise imports)  6.903050e+00
# 19  Transport services (% of commercial service ex...  1.987647e+01
# 8             Fuel exports (% of merchandise exports)  2.164245e+01
# 9             Fuel imports (% of merchandise imports)  2.221236e+01
# 22  Travel services (% of commercial service imports)  2.233662e+01
# 13    Manufactures imports (% of merchandise imports)  2.448035e+01
# 5   Computer, communications and other services (%...  3.011045e+01
# 16                       Merchandise trade (% of GDP)  3.027598e+01
# 12    Manufactures exports (% of merchandise exports)  3.524522e+01
# 21  Travel services (% of commercial service exports)  3.539185e+01
# 20  Transport services (% of commercial service im...  3.743287e+01
# 6             Food exports (% of merchandise exports)  3.810179e+01
# 4   Computer, communications and other services (%...  4.490652e+01
# 2            Commercial service exports (current US$)  1.127651e+11
# 3            Commercial service imports (current US$)  1.637525e+11
# 15                  Merchandise imports (current US$)  6.375470e+11
# 14                  Merchandise exports (current US$)  7.151202e+11

# %% [markdown]
# #### Filtros

# %% [markdown]
# Aplicaremos os métodos **ANOVA (F-values)** e **mutual information**

# %%
f, p = f_regression(X_train, y_train)

# %%
mi = mutual_info_regression(X_train, y_train)

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'F': f,
        'MI': mi,
        'Variance': vt.variances_
    }
).sort_values('MI', ascending=False).style.bar(subset=['F', 'MI', 'Variance'], color='grey')
# Out:
# <style type="text/css">
# #T_14113_row0_col1, #T_14113_row0_col2, #T_14113_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 100.0%, transparent 100.0%);
# }
# #T_14113_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 93.0%, transparent 93.0%);
# }
# #T_14113_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 99.3%, transparent 99.3%);
# }
# #T_14113_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 89.2%, transparent 89.2%);
# }
# #T_14113_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 21.8%, transparent 21.8%);
# }
# #T_14113_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 83.3%, transparent 83.3%);
# }
# #T_14113_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 22.9%, transparent 22.9%);
# }
# #T_14113_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 74.1%, transparent 74.1%);
# }
# #T_14113_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 82.6%, transparent 82.6%);
# }
# #T_14113_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 15.8%, transparent 15.8%);
# }
# #T_14113_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 7.0%, transparent 7.0%);
# }
# #T_14113_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 51.1%, transparent 51.1%);
# }
# #T_14113_row4_col3, #T_14113_row5_col3, #T_14113_row6_col3, #T_14113_row7_col3, #T_14113_row8_col3, #T_14113_row9_col3, #T_14113_row10_col3, #T_14113_row11_col3, #T_14113_row12_col3, #T_14113_row13_col3, #T_14113_row14_col3, #T_14113_row15_col3, #T_14113_row16_col3, #T_14113_row17_col3, #T_14113_row18_col1, #T_14113_row19_col3, #T_14113_row20_col3, #T_14113_row21_col3, #T_14113_row22_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.0%, transparent 0.0%);
# }
# #T_14113_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 4.0%, transparent 4.0%);
# }
# #T_14113_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 50.3%, transparent 50.3%);
# }
# #T_14113_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 5.1%, transparent 5.1%);
# }
# #T_14113_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 44.8%, transparent 44.8%);
# }
# #T_14113_row7_col1, #T_14113_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.0%, transparent 1.0%);
# }
# #T_14113_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 41.6%, transparent 41.6%);
# }
# #T_14113_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.1%, transparent 0.1%);
# }
# #T_14113_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 41.3%, transparent 41.3%);
# }
# #T_14113_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 4.7%, transparent 4.7%);
# }
# #T_14113_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 40.7%, transparent 40.7%);
# }
# #T_14113_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 40.0%, transparent 40.0%);
# }
# #T_14113_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.5%, transparent 1.5%);
# }
# #T_14113_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 33.9%, transparent 33.9%);
# }
# #T_14113_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 8.5%, transparent 8.5%);
# }
# #T_14113_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 30.3%, transparent 30.3%);
# }
# #T_14113_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.9%, transparent 0.9%);
# }
# #T_14113_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 21.7%, transparent 21.7%);
# }
# #T_14113_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.5%, transparent 0.5%);
# }
# #T_14113_row14_col2, #T_14113_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 20.0%, transparent 20.0%);
# }
# #T_14113_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.7%, transparent 0.7%);
# }
# #T_14113_row16_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.7%, transparent 1.7%);
# }
# #T_14113_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 18.7%, transparent 18.7%);
# }
# #T_14113_row17_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.3%, transparent 1.3%);
# }
# #T_14113_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 13.0%, transparent 13.0%);
# }
# #T_14113_row18_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 12.6%, transparent 12.6%);
# }
# #T_14113_row18_col3, #T_14113_row22_col1, #T_14113_row22_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_14113_row19_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.3%, transparent 0.3%);
# }
# #T_14113_row19_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 12.3%, transparent 12.3%);
# }
# #T_14113_row20_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.2%, transparent 0.2%);
# }
# #T_14113_row20_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 11.3%, transparent 11.3%);
# }
# #T_14113_row21_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.4%, transparent 0.4%);
# }
# #T_14113_row21_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 9.6%, transparent 9.6%);
# }
# </style>
# <table id="T_14113_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Feature</th>
#       <th class="col_heading level0 col1" >F</th>
#       <th class="col_heading level0 col2" >MI</th>
#       <th class="col_heading level0 col3" >Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14113_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_14113_row0_col0" class="data row0 col0" >Merchandise exports (current US$)</td>
#       <td id="T_14113_row0_col1" class="data row0 col1" >1803.805380</td>
#       <td id="T_14113_row0_col2" class="data row0 col2" >1.845353</td>
#       <td id="T_14113_row0_col3" class="data row0 col3" >715120200000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_14113_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_14113_row1_col0" class="data row1 col0" >Merchandise imports (current US$)</td>
#       <td id="T_14113_row1_col1" class="data row1 col1" >1678.207037</td>
#       <td id="T_14113_row1_col2" class="data row1 col2" >1.832326</td>
#       <td id="T_14113_row1_col3" class="data row1 col3" >637547050000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_14113_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_14113_row2_col0" class="data row2 col0" >Commercial service imports (current US$)</td>
#       <td id="T_14113_row2_col1" class="data row2 col1" >394.104046</td>
#       <td id="T_14113_row2_col2" class="data row2 col2" >1.544312</td>
#       <td id="T_14113_row2_col3" class="data row2 col3" >163752457384.853668</td>
#     </tr>
#     <tr>
#       <th id="T_14113_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_14113_row3_col0" class="data row3 col0" >Commercial service exports (current US$)</td>
#       <td id="T_14113_row3_col1" class="data row3 col1" >1337.453585</td>
#       <td id="T_14113_row3_col2" class="data row3 col2" >1.531142</td>
#       <td id="T_14113_row3_col3" class="data row3 col3" >112765058492.952179</td>
#     </tr>
#     <tr>
#       <th id="T_14113_level0_row4" class="row_heading level0 row4" >8</th>
#       <t

# %% [markdown]
# ### c) Seto público

# %% [markdown]
# Eliminando todos os NaN

# %%
df_public_SN.isna().sum().sort_values(ascending=False)
# Out:
# Multidimensional poverty intensity (average share of deprivations experienced by the poor)    50
# Presence of peace keepers (number of troops, police, and military observers in mandate)       50
# Multidimensional poverty headcount ratio (% of total population)                              50
# Multidimensional poverty headcount ratio, children (% of population ages 0-17)                50
# Multidimensional poverty headcount ratio, female (% of female population)                     50
#                                                                                               ..
# Arms imports (SIPRI trend indicator values)                                                    0
# Military expenditure (% of GDP)                                                                0
# Military expenditure (current LCU)                                                             0
# Refugee population by country or territory of asylum                                           0
# Value                                                                                          0
# Length: 328, dtype: int64

# %%
df_public_SN.dropna(axis=1, inplace=True)

# %% [markdown]
# #### Seleção das características mais úteis

# %%
df_train, df_test = train_test_split(df_public_SN, test_size=0.3)

# %%
X_train = df_train.drop('Value', axis=1)
X_test = df_train.drop('Value', axis=1)

# %%
y_train = df_train['Value']
y_train = df_train['Value']

# %% [markdown]
# #### VarianceThreshold

# %%
vt = VarianceThreshold(threshold=0)

# %%
vt.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
X_train = X_train.iloc[:, vt.get_support()]
X_test = X_test.iloc[:, vt.get_support()]

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'Variance': vt.variances_
    }
).sort_values('Variance', ascending=True)
# Out:
#                                              Feature      Variance
# 2                    Military expenditure (% of GDP)  1.839501e-01
# 6  Refugee population by country or territory of ...  7.329460e+04
# 5  Refugee population by country or territory of ...  1.594518e+05
# 1        Arms imports (SIPRI trend indicator values)  1.303667e+09
# 0        Arms exports (SIPRI trend indicator values)  1.919800e+09
# 4                 Military expenditure (current USD)  8.427204e+10
# 3                 Military expenditure (current LCU)  2.229501e+12

# %% [markdown]
# #### Filtros

# %% [markdown]
# Aplicaremos os métodos **ANOVA (F-values)** e **mutual information**

# %%
f, p = f_regression(X_train, y_train)

# %%
mi = mutual_info_regression(X_train, y_train)

# %%
pd.DataFrame(
    {
        'Feature': X_train.columns.tolist(),
        'F': f,
        'MI': mi,
        'Variance': vt.variances_
    }
).sort_values('F', ascending=False).style.bar(subset=['F', 'MI', 'Variance'], color='grey')
# Out:
# <style type="text/css">
# #T_69438_row0_col1, #T_69438_row2_col2, #T_69438_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 100.0%, transparent 100.0%);
# }
# #T_69438_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 95.8%, transparent 95.8%);
# }
# #T_69438_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 3.8%, transparent 3.8%);
# }
# #T_69438_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 73.5%, transparent 73.5%);
# }
# #T_69438_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 22.2%, transparent 22.2%);
# }
# #T_69438_row1_col3, #T_69438_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.1%, transparent 0.1%);
# }
# #T_69438_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 67.4%, transparent 67.4%);
# }
# #T_69438_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 15.8%, transparent 15.8%);
# }
# #T_69438_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 33.6%, transparent 33.6%);
# }
# #T_69438_row3_col3, #T_69438_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 0.0%, transparent 0.0%);
# }
# #T_69438_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 14.1%, transparent 14.1%);
# }
# #T_69438_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 15.2%, transparent 15.2%);
# }
# #T_69438_row4_col3, #T_69438_row5_col2, #T_69438_row6_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_69438_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 1.0%, transparent 1.0%);
# }
# #T_69438_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,grey 23.2%, transparent 23.2%);
# }
# </style>
# <table id="T_69438_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Feature</th>
#       <th class="col_heading level0 col1" >F</th>
#       <th class="col_heading level0 col2" >MI</th>
#       <th class="col_heading level0 col3" >Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69438_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_69438_row0_col0" class="data row0 col0" >Military expenditure (current USD)</td>
#       <td id="T_69438_row0_col1" class="data row0 col1" >86.898731</td>
#       <td id="T_69438_row0_col2" class="data row0 col2" >1.547523</td>
#       <td id="T_69438_row0_col3" class="data row0 col3" >84272043298.324707</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_69438_row1_col0" class="data row1 col0" >Arms exports (SIPRI trend indicator values)</td>
#       <td id="T_69438_row1_col1" class="data row1 col1" >65.191499</td>
#       <td id="T_69438_row1_col2" class="data row1 col2" >0.485669</td>
#       <td id="T_69438_row1_col3" class="data row1 col3" >1919800000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_69438_row2_col0" class="data row2 col0" >Military expenditure (current LCU)</td>
#       <td id="T_69438_row2_col1" class="data row2 col1" >60.179788</td>
#       <td id="T_69438_row2_col2" class="data row2 col2" >1.607594</td>
#       <td id="T_69438_row2_col3" class="data row2 col3" >2229501392226.814453</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_69438_row3_col0" class="data row3 col0" >Refugee population by country or territory of origin</td>
#       <td id="T_69438_row3_col1" class="data row3 col1" >17.857664</td>
#       <td id="T_69438_row3_col2" class="data row3 col2" >0.649867</td>
#       <td id="T_69438_row3_col3" class="data row3 col3" >73294.600000</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_69438_row4_col0" class="data row4 col0" >Military expenditure (% of GDP)</td>
#       <td id="T_69438_row4_col1" class="data row4 col1" >16.448331</td>
#       <td id="T_69438_row4_col2" class="data row4 col2" >0.385241</td>
#       <td id="T_69438_row4_col3" class="data row4 col3" >0.183950</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_69438_row5_col0" class="data row5 col0" >Arms imports (SIPRI trend indicator values)</td>
#       <td id="T_69438_row5_col1" class="data row5 col1" >5.700041</td>
#       <td id="T_69438_row5_col2" class="data row5 col2" >0.165808</td>
#       <td id="T_69438_row5_col3" class="data row5 col3" >1303666666.666667</td>
#     </tr>
#     <tr>
#       <th id="T_69438_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_69438_row6_col0" class="data row6 col0" >Refugee population by country or territory of asylum</td>
#       <td id="T_69438_row6_col1" class="data row6 col1" >4.901622</td>
#       <td id="T_69438_row6_col2" class="data row6 col2" >0.499598</td>
#       <td id="T_69438_row6_col3" class="data row6 col3" >159451.800000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ### 4) Comparando a economia com os setores público e privado
